# %%
import geopandas as gpd
geo_dir = './rawdatas/'

# %%
df1 = gpd.read_file(geo_dir + '빈격자1km/빈격자(1km).shp', encoding='utf-8')
df2 = gpd.read_file(geo_dir + 'gb_geos.geojson')

# %%
df1.crs
# Out:
# <Bound CRS: PROJCS["Korea 2000 / Unified CS",GEOGCS["Korea 200 ...>
# Name: Korea 2000 / Unified CS
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: Transformation from Korea 2000 to WGS84
# - method: Position Vector transformation (geog2D domain)
# Datum: Korean Geodetic Datum 2002
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich
# Source CRS: Korea 2000 / Unified CS

# %%
df1 = df1.to_crs('epsg:4326')

# %%
gb_grid = gpd.sjoin(df1, df2)

# %%
gb_grid.plot()
# Out:
# <Axes: >

# %%
# gb_grid.to_file('gb_grid.shp')
# Out:
# C:\Users\SAMSUNG\AppData\Local\Temp\ipykernel_15972\854439055.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gb_grid.to_file('gb_grid.shp')
